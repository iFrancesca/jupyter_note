# %%
from itertools import product
from math import sqrt

import gurobipy as gp
from gurobipy import GRB
import random

# Parameters
with open("D:\\base\\jupyter\\gurobi\\example\\C1.1.txt" ) as f:
    txt = f.readlines()
num_customers = 100
num_facilities = 50
cartesian_prod = list(product(range(num_facilities), range(num_customers)))

costs = list(i.split(" ") for i in txt[2:])
costs = [list(map(eval,cost[:-1])) for cost in costs]
#固定成本
setup_cost = [cost[1] for cost in costs ]
#运输成本
customs_to_facility = [cost[2:] for cost in costs]
shipping_cost = {(i,j): customs_to_facility[i][j] for i,j in cartesian_prod}
k=0

# %%
# MIP  model formulation

m = gp.Model('facility_location')

y = m.addVars(num_facilities, vtype=GRB.BINARY, name='Select')
x = m.addVars(cartesian_prod, vtype=GRB.CONTINUOUS, name='Assign')
z = m.addVar( vtype=GRB.CONTINUOUS, name='z')

m.addConstrs((gp.quicksum(x[(i,j)] for i in range(num_facilities)) == 1 \
              for j in range(num_customers)), name='Demand')
m.addConstrs((x[(i,j)] <= y[i] for i,j in cartesian_prod), name='Setup2ship')

m.setObjective(y.prod(setup_cost)+x.prod(shipping_cost), GRB.MINIMIZE)

m.optimize()
# Out:
# Using license file D:\programs\special\GUROBI\gurobi.lic
# Gurobi Optimizer version 9.1.0 build v9.1.0rc0 (win64)
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 5100 rows, 5051 columns and 15000 nonzeros
# Model fingerprint: 0x48189d66
# Variable types: 5001 continuous, 50 integer (50 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 2e+03]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 118359.00000
# Presolve removed 0 rows and 1 columns
# Presolve time: 0.02s
# Presolved: 5100 rows, 5050 columns, 15000 nonzeros
# Variable types: 5000 continuous, 50 integer (50 binary)
#
# Root relaxation: objective 1.603680e+04, 1166 iterations, 0.03 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 16036.8000    0   20 118359.000 16036.8000  86.5%     -    0s
# H    0     0                    35068.507692 16036.8000  54.3%     -    0s
# H    0     0                    19610.000000 16036.8000  18.2%     -    0s
#      0     0 16043.6783    0   23 19610.0000 16043.6783  18.2%     -    0s
#      0     0 16053.8195    0   26 19610.0000 16053.8195  18.1%     -    0s
#      0     0 16055.7650    0   25 19610.0000 16055.7650  18.1%     -    0s
#      0     0 16055.7650    0   25 19610.0000 16055.7650  18.1%     -    0s
# H    0     0                    18847.000000 16055.7650  14.8%     -    0s
# H    0     0                    16781.000000 16055.7650  4.32%     -    0s
#      0     2 16055.7650    0   25 16781.0000 16055.7650  4.32%     -    0s
#
# Cutting planes:
#   Gomory: 2
#
# Explored 26 nodes (3793 simplex iterations) in 0.67 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 5: 16781 18847 19610 ... 118359
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.678100000000e+04, best bound 1.678100000000e+04, gap 0.0000%

# %%
print("objVal:{} \n time:{}".format(m.ObjVal,m.getAttr(GRB.Attr.Runtime)))

for i in range(num_facilities):
    if y[i].X==1:
        print("facilities_open:{}".format(i))
for j in range(num_customers):
    select = dict()
    value = list(x[i,j].X for i in range(num_facilities))
    for i in range(len(value)):
        if value[i] != 0:
            select[i] = value[i]
    print("custome_{}:{}".format(j,select))
# Out:
# objVal:16781.0
#  time:0.67218017578125
# facilities_open:1
# facilities_open:4
# facilities_open:9
# facilities_open:21
# facilities_open:25
# facilities_open:42
# custome_0:{25: 1.0}
# custome_1:{21: 0.9999999999999998, 28: 2.220446049250313e-16}
# custome_2:{4: 0.9999999999999996, 28: 2.220446049250313e-16}
# custome_3:{21: 1.0}
# custome_4:{25: 1.0}
# custome_5:{21: 1.0}
# custome_6:{4: 0.9999999999999996, 15: 2.220446049250313e-16}
# custome_7:{25: 1.0}
# custome_8:{25: 1.0}
# custome_9:{21: 0.9999999999999996, 28: 2.220446049250313e-16}
# custome_10:{1: 0.9999999999999998, 15: 2.220446049250313e-16}
# custome_11:{21: 1.0}
# custome_12:{1: 1.0}
# custome_13:{1: 1.0}
# custome_14:{42: 1.0}
# custome_15:{25: 1.0}
