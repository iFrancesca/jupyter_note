# %%
import numpy as np
import pandas as pd

# %%
# 这里先要把优享和D1的两个题目从司机助手->司机部落
df1=pd.read_csv(r'D:\file\o\队长\满意度\队长对平台\11月\11月队长对平台满意度-快车.csv',encoding='gbk')
df1['业务线']='快车'
df2=pd.read_csv(r'D:\file\o\队长\满意度\队长对平台\11月\11月队长对平台满意度-优享.csv',encoding='gbk')
df2['业务线']='优享'
df3=pd.read_csv(r'D:\file\o\队长\满意度\队长对平台\11月\11月队长对平台满意度-D1.csv',encoding='gbk')
df3['业务线']='D1'
#dfinfo = pd.read_csv(r'D:\file\o\队长\满意度\队长对平台\问卷id匹配大区11.csv',encoding='gbk')
#dfinfo = pd.read_csv(r'D:\file\o\队长\满意度\队长对平台\11月\长-服-问卷id匹配大区.csv',encoding='gbk')
dfinfo = pd.read_csv(r'D:\file\o\队长\满意度\队长对平台\11月\队长基本信息匹配.csv',encoding='gbk')

# %%
# 问卷表
df=pd.concat([df1,df2,df3])
print(df.shape,dfinfo.shape)
df.rename(columns={'业务线':'问卷_业务线'},inplace=True)
df['UID'] = df['UID'].map(lambda x: x[1:]).astype(str)
print('总问卷数       ',df.shape[0])

# 信息表
dfinfo['司机队长id']=dfinfo.司机队长id.astype(str)
print('总队长数       ',dfinfo.shape[0])

# merge
dfall=pd.merge(df,dfinfo,how='left',left_on='UID',right_on='司机队长id')
d = dfall

# 分数转换
li = dfall.columns.tolist()[:9]

del li[5]   #筛选了'您对培训中以下哪方面不满意？'
for item in li:
    dfall[item] = dfall[item].str.split(':',expand=True)[1].values


# 筛选队长问卷
dfalll = dfall[dfall.司机队长id.notna()]
print('*'*20)
print('队长问卷数     ',dfalll.shape[0])

# 筛选每个队长的最后提交
dfall2 = dfalll.sort_values(by=['问卷_业务线','UID','提交时间'],ascending=False)
#dfall31 = dfall2[dfall2['业务线']==dfall2['问卷_业务线']]
dfall31 = dfall2.query(' 业务线 == 问卷_业务线')
print('删选重复业务线队长问卷数     ',dfall31.shape[0])

dfall3 = dfall31.drop_duplicates(subset=['UID'],keep='first')
print('有效队长问卷数 ',dfall3.shape[0])
# Out:
# (12053, 20) (20940, 8)
# 总问卷数        12053
# 总队长数        20940
# ********************
# 队长问卷数      8622
# 删选重复业务线队长问卷数      8560
# 有效队长问卷数  7235

# %%
#dfk = dfall3[dfall3['业务线']=='快车']
#dfx = dfall3[dfall3['业务线']=='优享']
#dfx = dfall3[dfall3['业务线']=='D1']

# %%
# 选取业务线
dfk = dfall3[dfall3['业务线']=='快车']
# 转为浮点数
dfk[['您是否认同担任司机小队队长给您带来荣誉感？', '您认为队长的日常服务要求内容是否合理？',
       '担任队长后，您认为每月的服务奖励能否达到您的期望值？','您认为司机部落工具是否可以帮助您更好的管理小队，例如及时查看团队数据和队长任务数据？',
       '您对司服经理召开的队长月度培训满意？', '您认为您的司机服务经理能否及时有效地帮您解决问题？',
       '您认为平台是否公平公正地评定队长的付出成果（如服务奖励的考核）？', '总体来说，您是否对担任小队队长满意？']]=dfk[[
       '您是否认同担任司机小队队长给您带来荣誉感？', '您认为队长的日常服务要求内容是否合理？',
       '担任队长后，您认为每月的服务奖励能否达到您的期望值？','您认为司机部落工具是否可以帮助您更好的管理小队，例如及时查看团队数据和队长任务数据？',
       '您对司服经理召开的队长月度培训满意？', '您认为您的司机服务经理能否及时有效地帮您解决问题？',
       '您认为平台是否公平公正地评定队长的付出成果（如服务奖励的考核）？', '总体来说，您是否对担任小队队长满意？']].astype(float)
# 计算分区域各指标mean值
dfkx = dfk.groupby(['大区'],as_index=False)[['您是否认同担任司机小队队长给您带来荣誉感？', '您认为队长的日常服务要求内容是否合理？',
       '担任队长后，您认为每月的服务奖励能否达到您的期望值？','您认为司机部落工具是否可以帮助您更好的管理小队，例如及时查看团队数据和队长任务数据？',
       '您对司服经理召开的队长月度培训满意？', '您认为您的司机服务经理能否及时有效地帮您解决问题？',
       '您认为平台是否公平公正地评定队长的付出成果（如服务奖励的考核）？', '总体来说，您是否对担任小队队长满意？']].mean()
# 计算各区总分
dfkx.loc[:,'总分']=dfkx[['您是否认同担任司机小队队长给您带来荣誉感？', '您认为队长的日常服务要求内容是否合理？',
       '担任队长后，您认为每月的服务奖励能否达到您的期望值？','您认为司机部落工具是否可以帮助您更好的管理小队，例如及时查看团队数据和队长任务数据？',
       '您对司服经理召开的队长月度培训满意？', '您认为您的司机服务经理能否及时有效地帮您解决问题？',
       '您认为平台是否公平公正地评定队长的付出成果（如服务奖励的考核）？', '总体来说，您是否对担任小队队长满意？']].sum(axis=1)
# 按区域名称排序
dfkx = dfkx.sort_values(by='大区',ascending=False)
# 计算全国各指标mean值
dfkx.loc['汇总']=dfk[['您是否认同担任司机小队队长给您带来荣誉感？', '您认为队长的日常服务要求内容是否合理？',
       '担任队长后，您认为每月的服务奖励能否达到您的期望值？','您认为司机部落工具是否可以帮助您更好的管理小队，例如及时查看团队数据和队长任务数据？',
       '您对司服经理召开的队长月度培训满意？', '您认为您的司机服务经理能否及时有效地帮您解决问题？',
       '您认为平台是否公平公正地评定队长的付出成果（如服务奖励的考核）？', '总体来说，您是否对担任小队队长满意？']].mean()
# 计算全国总分
dfkx.loc['汇总','总分']=dfkx.loc['汇总',['您是否认同担任司机小队队长给您带来荣誉感？', '您认为队长的日常服务要求内容是否合理？',
       '担任队长后，您认为每月的服务奖励能否达到您的期望值？','您认为司机部落工具是否可以帮助您更好的管理小队，例如及时查看团队数据和队长任务数据？',
       '您对司服经理召开的队长月度培训满意？', '您认为您的司机服务经理能否及时有效地帮您解决问题？',
       '您认为平台是否公平公正地评定队长的付出成果（如服务奖励的考核）？', '总体来说，您是否对担任小队队长满意？']].sum()
# 补全值
dfkx.loc['汇总','大区']='全国'
# Out:
# C:\Users\shenyajun_i\Anaconda3\lib\site-packages\pandas\core\frame.py:3191: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
# 选取业务线
dfy = dfall3[dfall3['业务线']=='优享']
# 转为浮点数
dfy[['您是否认同担任司机小队队长给您带来荣誉感？', '您认为队长的日常服务要求内容是否合理？',
       '担任队长后，您认为每月的服务奖励能否达到您的期望值？','您认为司机部落工具是否可以帮助您更好的管理小队，例如及时查看团队数据和队长任务数据？',
       '您对司服经理召开的队长月度培训满意？', '您认为您的司机服务经理能否及时有效地帮您解决问题？',
       '您认为平台是否公平公正地评定队长的付出成果（如服务奖励的考核）？', '总体来说，您是否对担任小队队长满意？']]=dfy[[
       '您是否认同担任司机小队队长给您带来荣誉感？', '您认为队长的日常服务要求内容是否合理？',
       '担任队长后，您认为每月的服务奖励能否达到您的期望值？','您认为司机部落工具是否可以帮助您更好的管理小队，例如及时查看团队数据和队长任务数据？',
       '您对司服经理召开的队长月度培训满意？', '您认为您的司机服务经理能否及时有效地帮您解决问题？',
       '您认为平台是否公平公正地评定队长的付出成果（如服务奖励的考核）？', '总体来说，您是否对担任小队队长满意？']].astype(float)
# 计算分区域各指标mean值
dfyx = dfy.groupby(['大区'],as_index=False)[['您是否认同担任司机小队队长给您带来荣誉感？', '您认为队长的日常服务要求内容是否合理？',
       '担任队长后，您认为每月的服务奖励能否达到您的期望值？','您认为司机部落工具是否可以帮助您更好的管理小队，例如及时查看团队数据和队长任务数据？',
       '您对司服经理召开的队长月度培训满意？', '您认为您的司机服务经理能否及时有效地帮您解决问题？',
       '您认为平台是否公平公正地评定队长的付出成果（如服务奖励的考核）？', '总体来说，您是否对担任小队队长满意？']].mean()
# 计算各区总分
dfyx.loc[:,'总分']=dfyx[['您是否认同担任司机小队队长给您带来荣誉感？', '您认为队长的日常服务要求内容是否合理？',
       '担任队长后，您认为每月的服务奖励能否达到您的期望值？','您认为司机部落工具是否可以帮助您更好的管理小队，例如及时查看团队数据和队长任务数据？',
       '您对司服经理召开的队长月度培训满意？', '您认为您的司机服务经理能否及时有效地帮您解决问题？',
       '您认为平台是否公平公正地评定队长的付出成果（如服务奖励的考核）？', '总体来说，您是否对担任小队队长满意？']].sum(axis=1)
# 按区域名称排序
dfyx = dfyx.sort_values(by='大区',ascending=False)
# 计算全国各指标mean值
dfyx.loc['汇总']=dfy[['您是否认同担任司机小队队长给您带来荣誉感？', '您认为队长的日常服务要求内容是否合理？',
       '担任队长后，您认为每月的服务奖励能否达到您的期望值？','您认为司机部落工具是否可以帮助您更好的管理小队，例如及时查看团队数据和队长任务数据？',
       '您对司服经理召开的队长月度培训满意？', '您认为您的司机服务经理能否及时有效地帮您解决问题？',
       '您认为平台是否公平公正地评定队长的付出成果（如服务奖励的考核）？', '总体来说，您是否对担任小队队长满意？']].mean()
# 计算全国总分
dfyx.loc['汇总','总分']=dfyx.loc['汇总',['您是否认同担任司机小队队长给您带来荣誉感？', '您认为队长的日常服务要求内容是否合理？',
       '担任队长后，您认为每月的服务奖励能否达到您的期望值？','您认为司机部落工具是否可以帮助您更好的管理小队，例如及时查看团队数据和队长任务数据？',
       '您对司服经理召开的队长月度培训满意？', '您认为您的司机服务经理能否及时有效地帮您解决问题？',
       '您认为平台是否公平公正地评定队长的付出成果（如服务奖励的考核）？', '总体来说，您是否对担任小队队长满意？']].sum()
# 补全值
dfyx.loc['汇总','大区']='全国'

# %%
# 选取业务线
dfd = dfall3[dfall3['业务线']=='D1']
# 转为浮点数
dfd[['您是否认同担任司机小队队长给您带来荣誉感？', '您认为队长的日常服务要求内容是否合理？',
       '担任队长后，您认为每月的服务奖励能否达到您的期望值？','您认为司机部落工具是否可以帮助您更好的管理小队，例如及时查看团队数据和队长任务数据？',
       '您对司服经理召开的队长月度培训满意？', '您认为您的司机服务经理能否及时有效地帮您解决问题？',
       '您认为平台是否公平公正地评定队长的付出成果（如服务奖励的考核）？', '总体来说，您是否对担任小队队长满意？']]=dfd[[
       '您是否认同担任司机小队队长给您带来荣誉感？', '您认为队长的日常服务要求内容是否合理？',
       '担任队长后，您认为每月的服务奖励能否达到您的期望值？','您认为司机部落工具是否可以帮助您更好的管理小队，例如及时查看团队数据和队长任务数据？',
       '您对司服经理召开的队长月度培训满意？', '您认为您的司机服务经理能否及时有效地帮您解决问题？',
       '您认为平台是否公平公正地评定队长的付出成果（如服务奖励的考核）？', '总体来说，您是否对担任小队队长满意？']].astype(float)
# 计算分区域各指标mean值
dfdx = dfd.groupby(['大区'],as_index=False)[['您是否认同担任司机小队队长给您带来荣誉感？', '您认为队长的日常服务要求内容是否合理？',
       '担任队长后，您认为每月的服务奖励能否达到您的期望值？','您认为司机部落工具是否可以帮助您更好的管理小队，例如及时查看团队数据和队长任务数据？',
       '您对司服经理召开的队长月度培训满意？', '您认为您的司机服务经理能否及时有效地帮您解决问题？',
       '您认为平台是否公平公正地评定队长的付出成果（如服务奖励的考核）？', '总体来说，您是否对担任小队队长满意？']].mean()
# 计算各区总分
dfdx.loc[:,'总分']=dfdx[['您是否认同担任司机小队队长给您带来荣誉感？', '您认为队长的日常服务要求内容是否合理？',
       '担任队长后，您认为每月的服务奖励能否达到您的期望值？','您认为司机部落工具是否可以帮助您更好的管理小队，例如及时查看团队数据和队长任务数据？',
       '您对司服经理召开的队长月度培训满意？', '您认为您的司机服务经理能否及时有效地帮您解决问题？',
       '您认为平台是否公平公正地评定队长的付出成果（如服务奖励的考核）？', '总体来说，您是否对担任小队队长满意？']].sum(axis=1)
# 按区域名称排序
dfdx = dfdx.sort_values(by='大区',ascending=False)
# 计算全国各指标mean值
dfdx.loc['汇总']=dfd[['您是否认同担任司机小队队长给您带来荣誉感？', '您认为队长的日常服务要求内容是否合理？',
       '担任队长后，您认为每月的服务奖励能否达到您的期望值？','您认为司机部落工具是否可以帮助您更好的管理小队，例如及时查看团队数据和队长任务数据？',
       '您对司服经理召开的队长月度培训满意？', '您认为您的司机服务经理能否及时有效地帮您解决问题？',
       '您认为平台是否公平公正地评定队长的付出成果（如服务奖励的考核）？', '总体来说，您是否对担任小队队长满意？']].mean()
# 计算全国总分
dfdx.loc['汇总','总分']=dfdx.loc['汇总',['您是否认同担任司机小队队长给您带来荣誉感？', '您认为队长的日常服务要求内容是否合理？',
       '担任队长后，您认为每月的服务奖励能否达到您的期望值？','您认为司机部落工具是否可以帮助您更好的管理小队，例如及时查看团队数据和队长任务数据？',
       '您对司服经理召开的队长月度培训满意？', '您认为您的司机服务经理能否及时有效地帮您解决问题？',
       '您认为平台是否公平公正地评定队长的付出成果（如服务奖励的考核）？', '总体来说，您是否对担任小队队长满意？']].sum()
# 补全值
dfdx.loc['汇总','大区']='全国'

# %%
#写入Excel&保存
writer = pd.ExcelWriter('D:/file/o/队长/满意度/队长对平台/11月/11月队长对平台.xlsx')
dfkx.to_excel(writer,'快车',index=False)
dfyx.to_excel(writer,'优享',index=False)
dfdx.to_excel(writer,'D1'  ,index=False)
dfall3.to_excel(writer,'快车优享D1问卷明细',index=False)
writer.save()

# %%
dfkx.columns
# Out:
# Index(['大区', '您是否认同担任司机小队队长给您带来荣誉感？', '您认为队长的日常服务要求内容是否合理？',
#        '担任队长后，您认为每月的服务奖励能否达到您的期望值？',
#        '您认为司机部落工具是否可以帮助您更好的管理小队，例如及时查看团队数据和队长任务数据？', '您对司服经理召开的队长月度培训满意？',
#        '您认为您的司机服务经理能否及时有效地帮您解决问题？', '您认为平台是否公平公正地评定队长的付出成果（如服务奖励的考核）？',
#        '总体来说，您是否对担任小队队长满意？', '总分'],
#       dtype='object')
