# %%
from openpyxl import load_workbook
import random
import re
from word_jieba import cut_word
#from dic import lt_to_dic
import Cdic

# %%
#将提取字段输入一个列表中
def get_lt(cells,lt):
    for cell in cells:
        c = cell[0].value
        lt.append(c)

#列表写入excel文件
            #填写要固定的列
def write(index,ws,lt):
    for i in range(len(lt)):
        ws.cell(2+i,index).value = lt[i]
        print(i,end=' ')
            #选择填入某行的单元格
            
def write_row(row,ws,content):
    ws.cell(row,1).value = content   #注意固定的那一列，*可选
    print(row,end=' ')
    

#去重空字符
def char(i):
    c = " "
    s = i.replace(c,"")
    return s
    
#处理字段
'''
#去除字段中部分内容
def func(i):
    if i is None:
        return None
    else:
        for ch in "[]1234567890-/\\n,，" :
            i = i.replace(ch,"")
        return i
'''

'''

#去除字段中部分内容
def func(i):
    if i is None:
        return None
    else:
        i = i.replace("例","")
        return i
'''

'''
提取字段中内容
def func(i):
    return i.split(" ")[0]
'''

'''
def get_comm(i):
     url = ""
     url = i+"list.htm"
     return url

def get_paper(i):
    url = ""
    url = i+"lanmu"
    return url

def getname(url_str):
    
    try:
        m = re.compile(r"https://(.*?).haodf.*?")
        s = m.findall(url_str)[0]
        return s.split("-")[0]
    except:
        print("error")
        print(url_str)
'''

def compute_value(dic):
    values = dic.values()
    return sum(values)

#输出形式
def prin(a,b):
    return '{}({})'.format(b,a)

# %%
  
#处理文件
path = 'D:\\file\\course\\电子商务\\hdf\\data\\new\\analysis\\1.医生个人主页.xlsx'  #填写路径
wb = load_workbook(path)
ws = wb["Sheet1"]   #填写工作簿名字
ws2 = wb["no"]

cells_e = ws["K2:K664"]
le = []
get_lt(cells_e,le)

print("read_ok")
# Out:
# read_ok

# %%
#处理字段
'''
ws = wb["Sheet1"]   #填写工作簿名字
ws2 = wb["no"]
'''

def func(i):
    if i is None:
        return None
    else:
        for ch in " ,，" :
            i = i.replace(ch,"")
        return i[:-1]
doc = [lei.split("\n")[1] for lei in le]

node_lt1 = map(func,doc)
node_lt1 = list(node_lt1)
print("list_ok")

write(12,ws2,node_lt1)
wb.save(path)
print('write_ok')
# Out:
# list_ok
# ...

# %%
doc = [lei.split("\n")[1] for lei in le]
a = doc[0]
def func(i):
    if i is None:
        return None
    else:
        for ch in " ,，" :
            i = i.replace(ch,"")
        return i[:-1]
b = func(a)
print(b)
# Out:
# 3821246

# %%
'''
#计算某一列的值 <格式[[a,3],[b,4]......]>
dic_items = list(map(dict,lt_items))
lt_com = list(map(compute_value,dic_items))
write(15,ws2,lt_com)
wb.save(path)
print('write_ok') 
'''


'''
node_lt = map(func,le)
node_lt = list(node_lt)
'''

'''
#随机抽样加入文件列表
node_lt = []
node_lt2 = []
for i in range(80):
    node_lt.append(le[random.randint(0,53)])  ##n-2
    node_lt2.append(le2[random.randint(0,53)])
print("list_ok")
'''







'''
lt_date = []
lt_doc = []

#在一个字典中加入指定列表作为指定键的值 
d = dict()
for i in range(len(le)):
    doc = le[i]
    date = le2[i]
    if doc in d:
        d.get(doc).append(date)
    else:
        d[doc] = []
        d.get(doc).append(date)

#每个医生随机抽样,抽取n个url
random.seed(40)
for doc in d.keys():
    doc_url = random.choices(d.get(doc),k=50)
    lt_url.extend(doc_url)
    lt_doc.extend(list(doc for i in range(len(doc_url))))

write(7,ws,lt_url)
write(8,ws,lt_doc)
wb.save(path)
print('write_ok')          
'''



'''
#speak进行分词
lt_items = list(map(cut_word,le))
lt_write_items=['' for i in range(len(lt_items))]
#将Items转换为写入excel文件的格式【list不能写入，要转化为str形式】
for i in range(len(lt_items)):
    s = str(lt_items[i])
    lt_write_items[i] = s
    
'''
'''
#写入excel
write(1,ws2,lt_doc)
write(2,ws2,lt_speak)
write(3,ws2,lt_num)
wb.save(path)
print('write_ok')   
'''


'''
def func(i):
    char = i.split("by")[-1]
    return char.strip("\n").strip(" ")
#补全姓名
S = set()
for name in le:
    try:
        if "医师" in name:
            S.add(name)
    except:
        print("set_error")
d = dict()
for s in S:
    d[s] = le.index(s)
node_lt = []
items = list(d.items())
items.sort(key=lambda x:x[1])
for i in range(31770):
    node_lt.append("")

for i in range(len(d)):
    try:
        a = items[i][1]
        b = items[i+1][1]
        for j in range(a,b):
            node_lt[j] = func(items[i][0])
    except:
        print("error_"+str(i))
        
'''



'''
#患者投票界面
cells_es = [ws['D2:D1697'],ws['E2:E1697'],ws['F2:F1697'],ws['G2:G1697'],\
            ws['H2:H1697'],ws['I2:I1697'],ws['J2:J1697']]

for i in range(4,11):
    cells_e = cells_es[i-4]
    print('rd_ok')
    le = []
    get_lt(cells_e,le)
    node_lt = map(func,le)
    node_lt = list(node_lt)
    write(i,ws2,node_lt)
    print("*"*30+str(i)+' list_ok')
    node_lt.clear()
'''
# Out:
# '\n#患者投票界面\ncells_es = [ws[\'D2:D1697\'],ws[\'E2:E1697\'],ws[\'F2:F1697\'],ws[\'G2:G1697\'],            ws[\'H2:H1697\'],ws[\'I2:I1697\'],ws[\'J2:J1697\']]\n\nfor i in range(4,11):\n    cells_e = cells_es[i-4]\n    print(\'rd_ok\')\n    le = []\n    get_lt(cells_e,le)\n    node_lt = map(func,le)\n    node_lt = list(node_lt)\n    write(i,ws2,node_lt)\n    print("*"*30+str(i)+\' list_ok\')\n    node_lt.clear()\n'
