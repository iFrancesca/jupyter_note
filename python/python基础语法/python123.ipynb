# %%
#计算标准差
'''

描述
编写一个函数计算一系列数的标准差。
‪‬‪‬‪‬‪‬‪‬‮‬‪‬‫‬‪‬‪‬‪‬‪‬‪‬‮‬‪‬‫‬‪‬‪‬‪‬‪‬‪‬‮‬‫‬‮‬‪‬‪‬‪‬‪‬‪‬‮‬‫‬‫‬‪‬‪‬‪‬‪‬‪‬‮‬‫‬‮‬‪‬‪‬‪‬‪‬‪‬‮‬‭‬‫‬
 
标准差定义：有一组数据S=s0,s1,s2,...,sn-1，其标准差表示为，其中 
‪‬‪‬‪‬‪‬‪‬‮‬‪‬‫‬‪‬‪‬‪‬‪‬‪‬‮‬‪‬‫‬‪‬‪‬‪‬‪‬‪‬‮‬‫‬‮‬‪‬‪‬‪‬‪‬‪‬‮‬‫‬‫‬‪‬‪‬‪‬‪‬‪‬‮‬‫‬‮‬‪‬‪‬‪‬‪‬‪‬‮‬‭‬‫‬
 
主程序输入若干个数，调用上述函数计算这些输入的数的标准差，并输出。
‪‬‪‬‪‬‪‬‪‬‮‬‪‬‫‬‪‬‪‬‪‬‪‬‪‬‮‬‪‬‫‬‪‬‪‬‪‬‪‬‪‬‮‬‫‬‮‬‪‬‪‬‪‬‪‬‪‬‮‬‫‬‫‬‪‬‪‬‪‬‪‬‪‬‮‬‫‬‮‬‪‬‪‬‪‬‪‬‪‬‮‬‭‬‫‬
 '''
from math import *
def m(t):
    M=0
    for i in t:
       M+=i
    return M/len(t)
def fd(t):
    D=0
    for i in t:
       D+=(i-m(t))**2
    return sqrt(D/(len(t)-1))
nums=eval(input())
print("标准差为{:.1f}".format(fd(nums)))
# Out:
# 22,26,55
# 标准差为18.0

# %%
#标题
'''编写一个函数，实现如下图所示数学分段函数的计算：
‪‬‪‬‪‬‪‬‪‬‮‬‪‬‫‬‪‬‪‬‪‬‪‬‪‬‮‬‪‬‫‬‪‬‪‬‪‬‪‬‪‬‮‬‫‬‮‬‪‬‪‬‪‬‪‬‪‬‮‬‫‬‫‬‪‬‪‬‪‬‪‬‪‬‮‬‫‬‮‬‪‬‪‬‪‬‪‬‪‬‮‬‭‬‫‬
 
  
‪‬‪‬‪‬‪‬‪‬‮‬‪‬‫‬‪‬‪‬‪‬‪‬‪‬‮‬‪‬‫‬‪‬‪‬‪‬‪‬‪‬‮‬‫‬‮‬‪‬‪‬‪‬‪‬‪‬‮‬‫‬‫‬‪‬‪‬‪‬‪‬‪‬‮‬‫‬‮‬‪‬‪‬‪‬‪‬‪‬‮‬‭‬‫‬
 
主程序调用该函数计算x为[a,b]区间内的奇数时对应y的值，
‪‬‪‬‪‬‪‬‪‬‮‬‪‬‫‬‪‬‪‬‪‬‪‬‪‬‮‬‪‬‫‬‪‬‪‬‪‬‪‬‪‬‮‬‫‬‮‬‪‬‪‬‪‬‪‬‪‬‮‬‫‬‫‬‪‬‪‬‪‬‪‬‪‬‮‬‫‬‮‬‪‬‪‬‪‬‪‬‪‬‮‬‭‬‫‬
 
a与b由用户输入得到。
‪‬‪‬‪‬‪‬‪‬‮‬‪‬‫‬‪‬‪‬‪‬‪‬‪‬‮‬‪‬‫‬‪‬‪‬‪‬‪‬‪‬‮‬‫‬‮‬‪‬‪‬‪‬‪‬‪‬‮‬‫‬‫‬‪‬‪‬‪‬‪‬‪‬‮‬‫‬‮‬‪‬‪‬‪‬‪‬‪‬‮‬‭‬‫‬
 
注意：复制下面代码，在#----#处填写代码，运行提交的程序中形如"#--提示文字--#"的提示信息不应于要运行的代码同行，可删去。
‪‬‪‬‪‬‪‬‪‬‮‬‪‬‫‬‪‬‪‬‪‬‪‬‪‬‮‬‪‬‫‬‪‬‪‬‪‬‪‬‪‬‮‬‫‬‮‬‪‬‪‬‪‬‪‬‪‬‮‬‫‬‫‬‪‬‪‬‪‬‪‬‪‬‮‬‫‬‮‬‪‬‪‬‪‬‪‬‪‬‮‬‭‬‫‬
 
from math import *
def fuction(x):
#--------------在以下空行处编写代码实现函数计算-------# 


#--------------在以上空行处编写代码实现函数计算-------# 

#以下为主程序
a,b=eval(input())
if a%2==0:
    a=a+1
for i in #---此处填空，填后删除短划线和#号---#  :
    print("f(%d)=%.2f"%( #---此处填空，填后删除短划线和#号---# )'''
from math import *
def fuction(x):
    if x>2:
        return abs(1.23*x-1.79)
    elif x==2:
        return e**x+x**3
    else:
        return cos(x)
a,b=eval(input())
if a%2==0:
    a=a+1
for i in range(a,b+1,2):
    print("f({})={:.2f}".format(i,fuction(i)))
# Out:
# -5,5
# f(-5)=0.28
# f(-3)=-0.99
# f(-1)=0.54
# f(1)=0.54
# f(3)=1.90
# f(5)=4.36

# %%
#统计字符串中指定类型字符的个数
'''描述
假设所有字符分为三类：字母，数字及其他字符。
‪‬‪‬‪‬‪‬‪‬‮‬‪‬‫‬‪‬‪‬‪‬‪‬‪‬‮‬‪‬‫‬‪‬‪‬‪‬‪‬‪‬‮‬‫‬‮‬‪‬‪‬‪‬‪‬‪‬‮‬‫‬‫‬‪‬‪‬‪‬‪‬‪‬‮‬‫‬‮‬‪‬‪‬‪‬‪‬‪‬‮‬‭‬‫‬
 
编写一个函数，判断指定字符的类型，并统计字符串中该类型字符的个数。
‪‬‪‬‪‬‪‬‪‬‮‬‪‬‫‬‪‬‪‬‪‬‪‬‪‬‮‬‪‬‫‬‪‬‪‬‪‬‪‬‪‬‮‬‫‬‮‬‪‬‪‬‪‬‪‬‪‬‮‬‫‬‫‬‪‬‪‬‪‬‪‬‪‬‮‬‫‬‮‬‪‬‪‬‪‬‪‬‪‬‮‬‭‬‫‬
 
主程序输入一个字符串及一个字符，调用上述函数统计该字符同类型字符在该字符串中的个数。
‪‬‪‬‪‬‪‬‪‬‮‬‪‬‫‬‪‬‪‬‪‬‪‬‪‬‮‬‪‬‫‬‪‬‪‬‪‬‪‬‪‬‮‬‫‬‮‬‪‬‪‬‪‬‪‬‪‬‮‬‫‬‫‬‪‬‪‬‪‬‪‬‪‬‮‬‫‬‮‬‪‬‪‬‪‬‪‬‪‬‮‬‭‬‫‬
 
 注意：复制下面代码，在指定位置处填写代码。
‪‬‪‬‪‬‪‬‪‬‮‬‪‬‫‬‪‬‪‬‪‬‪‬‪‬‮‬‪‬‫‬‪‬‪‬‪‬‪‬‪‬‮‬‫‬‮‬‪‬‪‬‪‬‪‬‪‬‮‬‫‬‫‬‪‬‪‬‪‬‪‬‪‬‮‬‫‬‮‬‪‬‪‬‪‬‪‬‪‬‮‬‭‬‫‬
 
#--------在以下空行处编写function函数代码----------------#

#--------在以下空行处编写function函数代码----------------#
#以下为主程序
s=input()
ch=input()
print("与%c同类型的字符有%d个。"%(ch,function(s,ch)))'''
def isnum(n):
    if ord('0')<=ord(n)<=ord('9'):
        return True
    else:
        return False
def isalph(n):
    N=n.lower()
    if ord('a')<=ord(n)<=ord('z'):
        return True
    else:
        return False
def isother(n):
    if not isnum(n) and not isalph(n):
        return True
def function(y,x):
    k=0
    if isnum(x):
        for i in y:
            if isnum(i):
                k+=1
    if isalph(x):
        for i in y:
            if isalph(i):
                k+=1
    if isother(x):
        for i in y:
            if isother(i):
                k+=1
    return k
s=input()
ch=input()
print("与{}同类型的字符有{}个。".format(ch,function(s,ch)))
# Out:
# jjjjj56123478/*-+39840
# @
# 与@同类型的字符有4个。

# %%
#等差数列的第n项
'''描述
等差数列是指从第二项起，每一项与它的前一项的差等于同一个常数的一种数列，这个常数叫做等差数列的公差。
‪‬‪‬‪‬‪‬‪‬‮‬‪‬‫‬‪‬‪‬‪‬‪‬‪‬‮‬‪‬‫‬‪‬‪‬‪‬‪‬‪‬‮‬‫‬‮‬‪‬‪‬‪‬‪‬‪‬‮‬‫‬‫‬‪‬‪‬‪‬‪‬‪‬‮‬‫‬‮‬‪‬‪‬‪‬‪‬‪‬‮‬‭‬‫‬
 
例如数列a: 1、4、7、10、13、16、19......公差为3
‪‬‪‬‪‬‪‬‪‬‮‬‪‬‫‬‪‬‪‬‪‬‪‬‪‬‮‬‪‬‫‬‪‬‪‬‪‬‪‬‪‬‮‬‫‬‮‬‪‬‪‬‪‬‪‬‪‬‮‬‫‬‫‬‪‬‪‬‪‬‪‬‪‬‮‬‫‬‮‬‪‬‪‬‪‬‪‬‪‬‮‬‭‬‫‬
 
例如数列b: 2、7、12、17、22、27、32......公差为5
‪‬‪‬‪‬‪‬‪‬‮‬‪‬‫‬‪‬‪‬‪‬‪‬‪‬‮‬‪‬‫‬‪‬‪‬‪‬‪‬‪‬‮‬‫‬‮‬‪‬‪‬‪‬‪‬‪‬‮‬‫‬‫‬‪‬‪‬‪‬‪‬‪‬‮‬‫‬‮‬‪‬‪‬‪‬‪‬‪‬‮‬‭‬‫‬
 
编写一个函数，指定首项、公差，返回数列中的第n项数
‪‬‪‬‪‬‪‬‪‬‮‬‪‬‫‬‪‬‪‬‪‬‪‬‪‬‮‬‪‬‫‬‪‬‪‬‪‬‪‬‪‬‮‬‫‬‮‬‪‬‪‬‪‬‪‬‪‬‮‬‫‬‫‬‪‬‪‬‪‬‪‬‪‬‮‬‫‬‮‬‪‬‪‬‪‬‪‬‪‬‮‬‭‬‫‬
 
例如指定首项为1、公差为3，返回数列中第5项为13
‪‬‪‬‪‬‪‬‪‬‮‬‪‬‫‬‪‬‪‬‪‬‪‬‪‬‮‬‪‬‫‬‪‬‪‬‪‬‪‬‪‬‮‬‫‬‮‬‪‬‪‬‪‬‪‬‪‬‮‬‫‬‫‬‪‬‪‬‪‬‪‬‪‬‮‬‫‬‮‬‪‬‪‬‪‬‪‬‪‬‮‬‭‬‫‬
 
又如指定首项为2、公差为5，返回数列中第6项为27
‪‬‪‬‪‬‪‬‪‬‮‬‪‬‫‬‪‬‪‬‪‬‪‬‪‬‮‬‪‬‫‬‪‬‪‬‪‬‪‬‪‬‮‬‫‬‮‬‪‬‪‬‪‬‪‬‪‬‮‬‫‬‫‬‪‬‪‬‪‬‪‬‪‬‮‬‫‬‮‬‪‬‪‬‪‬‪‬‪‬‮‬‭‬‫‬
 
主程序输入首项a、公差d、项数n，调用上述函数计算得到该等差数列的第n项的元素
‪‬‪‬‪‬‪‬‪‬‮‬‪‬‫‬‪‬‪‬‪‬‪‬‪‬‮‬‪‬‫‬‪‬‪‬‪‬‪‬‪‬‮‬‫‬‮‬‪‬‪‬‪‬‪‬‪‬‮‬‫‬‫‬‪‬‪‬‪‬‪‬‪‬‮‬‫‬‮‬‪‬‪‬‪‬‪‬‪‬‮‬‭‬‫‬
 
主程序已写好，请复制下列代码，补充完整。'''
‪‬‪‬‪‬‪‬‪‬‮‬‪‬‫‬‪‬‪‬‪‬‪‬‪‬‮‬‪‬‫‬‪‬‪‬‪‬‪‬‪‬‮‬‫‬‮‬‪‬‪‬‪‬‪‬‪‬‮‬‫‬‫‬‪‬‪‬‪‬‪‬‪‬‮‬‫‬‮‬‪‬‪‬‪‬‪‬‪‬‮‬‭‬‫‬
 
def suite(a,d,n):
    if n==1:
        an=a
    else:
        an=suite(a,d,n-1)+d
    return an
a,d,n=eval(input())
an=suite(a,d,n)
print(an)
# Out:
#   File "<ipython-input-1-fa513c4d464f>", line 25
#     ‪‬‪‬‪‬‪‬‪‬‮‬‪‬‫‬‪‬‪‬‪‬‪‬‪‬‮‬‪‬‫‬‪‬‪‬‪‬‪‬‪‬‮‬‫‬‮‬‪‬‪‬‪‬‪‬‪‬‮‬‫‬‫‬‪‬‪‬‪‬‪‬‪‬‮‬‫‬‮‬‪‬‪‬‪‬‪‬‪‬‮‬‭‬‫‬
#                                                                                                    ^
# SyntaxError: invalid character in identifier

# %%
#数字鲁棒
def iscomplex(n):
    for i in n:
        if i=='+':
            if n[-1]!='j':
                return False
                break

    return True
def isint(n):
    for i in str(eval(n)):
        if ord('0')>ord(i) or ord(i)>ord('9'):
            return False
            break
    else:
        return True
def int2(n):      
    l=[]
    ll=[]
    for i in n:
        l.append(i)
    for i in str(eval(n)):
        ll.append(i)
    if ll!=l:
        return True
    else:
        return False
def isnum(n):
    try:
        n=eval(n)
        return True
    except:
        return False
n=input()
N=0
if isnum(n):
    if not isint(n):
        if  iscomplex(n):
            N=eval(n)
            print(N**2)
    elif int2(n):
        print('输入有误')
    else:
        N=eval(n)
        print(N**2)
else:
    print('输入有误')
    
    
s = input()
try:
    if complex(s) == complex(eval(s)):
        print(eval(s)**2)
except:
    print("输入有误")
# Out:
# 56+
# 输入有误
