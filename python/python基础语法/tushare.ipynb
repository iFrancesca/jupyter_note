# %%
import tushare as ts
help(ts.cpi)
cpi.cpi.isnall()
cpi.cpi.dropna()
cpi.cpi.plot()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-4ed5b4b97096> in <module>()
#       1 import tushare as ts
# ----> 2 help(ts.cpi)
#       3 cpi.cpi.isnall()
#       4 cpi.cpi.dropna()
#       5 cpi.cpi.plot()
#
# AttributeError: module 'tushare' has no attribute 'cpi'

# %%
loan=ts.get_loan_rate()
print(loan)
print(loan.info())
loan.head()
print(loan.rate)
mean=loan[loan.loan_type=='个人住房商业贷款(三至五年)']
print(mean.head())
mean=mean.rate.astype(float)
print(mean.plot())
# Out:
#            date            loan_type   rate
# 0    2015-10-24          短期贷款(六个月以内)   4.35
# 1    2015-10-24         短期贷款(六个月至一年)   4.35
# 2    2015-10-24          中长期贷款(三至五年)   4.75
# 3    2015-10-24          中长期贷款(五年以上)   4.90
# 4    2015-10-24          中长期贷款(一至三年)   4.75
# 5    2015-10-24               贴现(贴现)     --
# 6    2015-10-24         优惠贷款(扶贫贴息贷款)     --
# 7    2015-10-24     优惠贷款(老少边穷发展经济贷款)     --
# 8    2015-10-24     优惠贷款(民政部门福利工厂贷款)     --
# 9    2015-10-24  优惠贷款(民族贸易及民族用品生产贷款)     --
# 10   2015-10-24       优惠贷款(贫困县办工业贷款)     --
# 11   2015-10-24      个人住房商业贷款(六个月以内)   3.92
# 12   2015-10-24     个人住房商业贷款(六个月至一年)   3.92
# 13   2015-10-24       个人住房商业贷款(三至五年)   4.28
# 14   2015-10-24       个人住房商业贷款(五年以上)   4.41
# 15   2015-10-24       个人住房商业贷款(一至三年)   4.28
# 16   2015-10-24      个人住房公积金贷款(五年以上)   3.25
# 17   2015-10-24      个人住房公积金贷款(五年以下)   2.75
# 18   2015-09-06            再贴现(再贴现率)   2.25
# 19   2015-08-26          短期贷款(六个月以内)   4.60
# ...

# %%
print(loan.replace(0,NaN))
print(loan.replace(0,np.NaN,inplace=True))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-4cbfd1591945> in <module>()
# ----> 1 print(loan.replace(0,NaN))
#       2 print(loan.replace(0,np.NaN,inplace=True))
#
# NameError: name 'NaN' is not defined

# %%
ms=ts.get_money_supply()
print(ms)
help(ts.get_money_supply)
# Out:
#        month          m2 m2_yoy         m1 m1_yoy        m0  m0_yoy  \
# 0     2019.4  1884670.33   8.50  540614.60   2.90  73965.76    3.50
# 1     2019.3  1889412.14   8.60  547575.54   4.60  74941.58    3.10
# 2     2019.2  1867427.45   8.00  527190.48   2.00  79484.72   -2.40
# 3     2019.1  1865935.33   8.40  545638.46   0.40  87470.62   17.20
# 4    2018.12  1826744.22   8.10  551685.91   1.50  73208.40    3.60
# 5    2018.11  1813175.07   8.00  543498.66   1.50  70563.30    2.80
# 6    2018.10  1795561.60   8.00  540128.37   2.70  70106.62    2.80
# 7     2018.9  1801665.58   8.30  538574.08   4.00  71254.26    2.20
# 8     2018.8  1788670.43   8.20  538324.64   3.90  69775.39    3.30
# 9     2018.7  1776196.11   8.50  536624.29   5.10  69530.59    3.60
# 10    2018.6  1770178.37   8.30  543944.71   6.00  69589.33    3.60
# 11    2018.5  1743063.79   8.30  526276.72   6.00  69774.81    3.60
# 12    2018.4  1737683.73   8.30  525447.77   7.20  71476.46    4.50
# ...

# %%
print(ms[['mO','sd','month']])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-f648c4257168> in <module>()
# ----> 1 print(ms[['mO','sd','month']])
#
# ~\Anaconda3\AAAA\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2677         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2678             # either boolean or fancy integer index
# -> 2679             return self._getitem_array(key)
#    2680         elif isinstance(key, DataFrame):
#    2681             return self._getitem_frame(key)
#
# ~\Anaconda3\AAAA\lib\site-packages\pandas\core\frame.py in _getitem_array(self, key)
#    2721             return self._take(indexer, axis=0)
#    2722         else:
# -> 2723             indexer = self.loc._convert_to_indexer(key, axis=1)
#    2724             return self._take(indexer, axis=1)
#    2725
#
# ...
